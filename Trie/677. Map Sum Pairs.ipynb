# %% [markdown]
# ### Use diff to record the difference between the new score of the word and the former stored in the score hash table.

# %%
class MapSum(object):

    def __init__(self):
        self.child={}
        self.map={}
        self.score=0

    def insert(self, key, val):
        """
        :type key: str
        :type val: int
        :rtype: None
        """
        diff=val-self.map.get(key,0)
        self.map[key]=val
        node=self
        for char in key:
            if char not in node.child:
                node.child[char]=MapSum()
            node=node.child[char]
            node.score+=diff

    def sum(self, prefix):
        """
        :type prefix: str
        :rtype: int
        """
        node=self
        for char in prefix:
            if char not in node.child:
                return 0
            node=node.child[char]
        return node.score

# Your MapSum object will be instantiated and called as such:
# obj = MapSum()
# obj.insert(key,val)
# param_2 = obj.sum(prefix)
